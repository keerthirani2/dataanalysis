# %%
import pandas as pd
df = pd.read_csv("meat_consumption.csv")
df
# Out:
#       location    indicator subject     measure frequency  time       value
# 0          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1990    0.000004
# 1          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1991   27.808401
# 2          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1992   26.278166
# 3          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1993   26.244478
# 4          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1994   25.541244
# ...        ...          ...     ...         ...       ...   ...         ...
# 12135     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2024  732.149998
# 12136     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2025  737.008238
# 12137     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2026  741.104095
# 12138     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2027  743.489549
# 12139     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2028  747.011872
#
# [12140 rows x 7 columns]

# %%
df.head(10)
# Out:
#   location    indicator subject measure frequency  time      value
# 0      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1990   0.000004
# 1      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1991  27.808401
# 2      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1992  26.278166
# 3      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1993  26.244478
# 4      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1994  25.541244
# 5      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1995  25.407555
# 6      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1996  27.328711
# 7      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1997  28.873698
# 8      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1998  26.653349
# 9      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1999  27.981665

# %%
df.value_counts()
# Out:
# location  indicator    subject  measure     frequency  time  value
# ARG       MEATCONSUMP  BEEF     KG_CAP      A          1990  55.369995      1
# PAK       MEATCONSUMP  BEEF     KG_CAP      A          1995  4.825720       1
# OECD      MEATCONSUMP  SHEEP    THND_TONNE  A          2025  2118.693847    1
#                                                        2026  2129.753003    1
#                                                        2027  2139.771709    1
#                                                                            ..
# IDN       MEATCONSUMP  BEEF     KG_CAP      A          1994  1.413389       1
#                                                        1995  1.313609       1
#                                                        1996  1.460437       1
#                                                        1997  1.491700       1
# ZAF       MEATCONSUMP  SHEEP    THND_TONNE  A          2028  189.504511     1
# Name: count, Length: 12140, dtype: int64

# %%
df.shape
# Out:
# (12140, 7)

# %%
df.describe()
# Out:
#                time         value
# count  12140.000000  1.214000e+04
# mean    2009.042175  2.245855e+03
# std       11.233660  1.040812e+04
# min     1990.000000  7.505681e-08
# 25%     1999.000000  5.013586e+00
# 50%     2009.000000  2.427455e+01
# 75%     2019.000000  4.355984e+02
# max     2028.000000  1.402526e+05

# %%
df.groupby(by='frequency')

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.drop_duplicates()
# Out:
#       location    indicator subject     measure frequency  time       value
# 0          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1990    0.000004
# 1          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1991   27.808401
# 2          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1992   26.278166
# 3          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1993   26.244478
# 4          AUS  MEATCONSUMP    BEEF      KG_CAP         A  1994   25.541244
# ...        ...          ...     ...         ...       ...   ...         ...
# 12135     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2024  732.149998
# 12136     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2025  737.008238
# 12137     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2026  741.104095
# 12138     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2027  743.489549
# 12139     EU27  MEATCONSUMP   SHEEP  THND_TONNE         A  2028  747.011872
#
# [12140 rows x 7 columns]

# %%
df.sample(n=20)
# Out:
#       location    indicator  subject     measure frequency  time         value
# 9439       WLD  MEATCONSUMP     BEEF  THND_TONNE         A  2019  70479.648737
# 1337       ARG  MEATCONSUMP  POULTRY      KG_CAP         A  2001     21.908411
# 3864       PER  MEATCONSUMP    SHEEP      KG_CAP         A  2013      1.190487
# 9085       AUS  MEATCONSUMP      PIG  THND_TONNE         A  2016    664.656380
# 4820       VNM  MEATCONSUMP     BEEF      KG_CAP         A  2002      1.719866
# 8056       TUR  MEATCONSUMP      PIG  THND_TONNE         A  2001      0.063100
# 2990       KAZ  MEATCONSUMP      PIG      KG_CAP         A  1993      9.372965
# 7350       RUS  MEATCONSUMP      PIG  THND_TONNE         A  1997   2240.444414
# 552        KOR  MEATCONSUMP  POULTRY      KG_CAP         A  1996      9.086526
# 6494       EGY  MEATCONSUMP     BEEF  THND_TONNE         A  1999    690.106118
# 11269      KOR  MEATCONSUMP  POULTRY  THND_TONNE         A  2016   1007.945104
# ...

# %%
df1 =df.drop(columns=['frequency','indicator'])
df1
# Out:
#       location subject     measure  time       value
# 0          AUS    BEEF      KG_CAP  1990    0.000004
# 1          AUS    BEEF      KG_CAP  1991   27.808401
# 2          AUS    BEEF      KG_CAP  1992   26.278166
# 3          AUS    BEEF      KG_CAP  1993   26.244478
# 4          AUS    BEEF      KG_CAP  1994   25.541244
# ...        ...     ...         ...   ...         ...
# 12135     EU27   SHEEP  THND_TONNE  2024  732.149998
# 12136     EU27   SHEEP  THND_TONNE  2025  737.008238
# 12137     EU27   SHEEP  THND_TONNE  2026  741.104095
# 12138     EU27   SHEEP  THND_TONNE  2027  743.489549
# 12139     EU27   SHEEP  THND_TONNE  2028  747.011872
#
# [12140 rows x 5 columns]

# %%
df2 = df1.loc[df['time']>2000]
df2
# Out:
#       location subject     measure  time       value
# 11         AUS    BEEF      KG_CAP  2001   24.511331
# 12         AUS    BEEF      KG_CAP  2002   25.166736
# 13         AUS    BEEF      KG_CAP  2003   25.861883
# 14         AUS    BEEF      KG_CAP  2004   28.619699
# 15         AUS    BEEF      KG_CAP  2005   27.108576
# ...        ...     ...         ...   ...         ...
# 12135     EU27   SHEEP  THND_TONNE  2024  732.149998
# 12136     EU27   SHEEP  THND_TONNE  2025  737.008238
# 12137     EU27   SHEEP  THND_TONNE  2026  741.104095
# 12138     EU27   SHEEP  THND_TONNE  2027  743.489549
# 12139     EU27   SHEEP  THND_TONNE  2028  747.011872
#
# [8736 rows x 5 columns]

# %%
df3 = df2.loc[df['time']<=2023]
df3
# Out:
#       location subject     measure  time       value
# 11         AUS    BEEF      KG_CAP  2001   24.511331
# 12         AUS    BEEF      KG_CAP  2002   25.166736
# 13         AUS    BEEF      KG_CAP  2003   25.861883
# 14         AUS    BEEF      KG_CAP  2004   28.619699
# 15         AUS    BEEF      KG_CAP  2005   27.108576
# ...        ...     ...         ...   ...         ...
# 12130     EU27   SHEEP  THND_TONNE  2019  701.700758
# 12131     EU27   SHEEP  THND_TONNE  2020  708.116261
# 12132     EU27   SHEEP  THND_TONNE  2021  713.002977
# 12133     EU27   SHEEP  THND_TONNE  2022  718.278440
# 12134     EU27   SHEEP  THND_TONNE  2023  725.136237
#
# [7176 rows x 5 columns]

# %%
df4 = df3.sample(n=20)
df4.plot.scatter(x='location',y='value')
# Out:
# <AxesSubplot:xlabel='location', ylabel='value'>

# %%
df3.location
# Out:
# 11        AUS
# 12        AUS
# 13        AUS
# 14        AUS
# 15        AUS
#          ...
# 12130    EU27
# 12131    EU27
# 12132    EU27
# 12133    EU27
# 12134    EU27
# Name: location, Length: 7176, dtype: object

# %%
df3.max()
# Out:
# location              ZAF
# subject             SHEEP
# measure        THND_TONNE
# time                 2023
# value       131197.190698
# dtype: object

# %%
df5 = df3.drop(columns=['measure'])
df5
# Out:
#       location subject  time       value
# 11         AUS    BEEF  2001   24.511331
# 12         AUS    BEEF  2002   25.166736
# 13         AUS    BEEF  2003   25.861883
# 14         AUS    BEEF  2004   28.619699
# 15         AUS    BEEF  2005   27.108576
# ...        ...     ...   ...         ...
# 12130     EU27   SHEEP  2019  701.700758
# 12131     EU27   SHEEP  2020  708.116261
# 12132     EU27   SHEEP  2021  713.002977
# 12133     EU27   SHEEP  2022  718.278440
# 12134     EU27   SHEEP  2023  725.136237
#
# [7176 rows x 4 columns]

# %%
data1 = pd.read_csv('data1.csv')
data1
# Out:
#    subject location   Sum of value
# 0    SHEEP      ARG    2245.512499
# 1    SHEEP      AUS   10933.888020
# 2    SHEEP      BRA    4752.071549
# 3    SHEEP    BRICS  192789.180700
# 4    SHEEP      CAN    1367.495218
# 5    SHEEP      CHE     532.502647
# 6    SHEEP      CHL     431.226326
# 7    SHEEP      CHN  145444.401300
# 8    SHEEP      COL     414.180367
# 9    SHEEP      EGY    4847.806018
# 10   SHEEP      ETH    3061.113745
# 11   SHEEP     EU27   24445.099790
# 12   SHEEP      GBR    9818.353170
# 13   SHEEP      IDN    4596.794790
# 14   SHEEP      IND   27797.083030
# 15   SHEEP      IRN   15744.411530
# 16   SHEEP      ISR     541.842559
# 17   SHEEP      JPN    1727.193965
# 18   SHEEP      KAZ    6782.974977
# 19   SHEEP      KOR     454.964157
# 20   SHEEP      MEX    2972.815737
# 21   SHEEP      MYS    1088.201811
# 22   SHEEP      NGA   14115.887200
# 23   SHEEP      NOR    1222.461184
# 24   SHEEP      NZL    3065.433816
# 25   SHEEP     OECD   76636.668460
# ...

# %%
data2 = pd.read_csv('data2.csv')
data2
# Out:
#     subject location  Sum of value
# 0   POULTRY      ARG  5.393800e+04
# 1   POULTRY      AUS  3.726184e+04
# 2   POULTRY      BRA  2.752745e+05
# 3   POULTRY    BRICS  1.131228e+06
# 4   POULTRY      CAN  4.788905e+04
# 5   POULTRY      CHE  5.006929e+03
# 6   POULTRY      CHL  2.277114e+04
# 7   POULTRY      CHN  5.717047e+05
# 8   POULTRY      COL  4.581553e+04
# 9   POULTRY      EGY  3.794192e+04
# 10  POULTRY      ETH  1.329717e+03
# 11  POULTRY     EU27  3.073802e+05
# 12  POULTRY      GBR  5.712313e+04
# 13  POULTRY      IDN  6.317912e+04
# 14  POULTRY      IND  9.295690e+04
# 15  POULTRY      IRN  6.027265e+04
# 16  POULTRY      ISR  2.153242e+04
# 17  POULTRY      JPN  8.239638e+04
# 18  POULTRY      KAZ  9.043005e+03
# 19  POULTRY      KOR  2.986101e+04
# 20  POULTRY      MEX  1.217323e+05
# 21  POULTRY      MYS  5.131452e+04
# 22  POULTRY      NGA  7.802680e+03
# 23  POULTRY      NOR  3.379363e+03
# 24  POULTRY      NZL  7.202358e+03
# 25  POULTRY     OECD  1.394269e+06
# ...

# %%
data3 = pd.read_csv('data3.csv')
data3
# Out:
#    subject location  Sum of value
# 0      PIG      ARG  1.623060e+04
# 1      PIG      AUS  2.183077e+04
# 2      PIG      BRA  1.010892e+05
# 3      PIG    BRICS  2.049493e+06
# 4      PIG      CAN  3.164899e+04
# 5      PIG      CHE  1.082451e+04
# 6      PIG      CHL  1.418065e+04
# 7      PIG      CHN  1.814999e+06
# 8      PIG      COL  1.191381e+04
# 9      PIG      EGY  7.808260e+01
# 10     PIG      ETH  7.036734e+01
# 11     PIG     EU27  5.712216e+05
# 12     PIG      GBR  4.141691e+04
# 13     PIG      IDN  1.535225e+04
# 14     PIG      IND  1.495554e+04
# 15     PIG      IRN  2.300567e+01
# 16     PIG      ISR  6.382577e+02
# 17     PIG      JPN  9.358561e+04
# 18     PIG      KAZ  5.422426e+03
# 19     PIG      KOR  5.723335e+04
# 20     PIG      MEX  6.537811e+04
# 21     PIG      MYS  9.217458e+03
# 22     PIG      NGA  8.460084e+03
# 23     PIG      NOR  5.511634e+03
# 24     PIG      NZL  4.060647e+03
# 25     PIG     OECD  1.259189e+06
# ...

# %%
data4 = pd.read_csv('data4.csv')
data4
# Out:
#    subject location  Sum of value
# 0     BEEF      ARG  9.811123e+04
# 1     BEEF      AUS  2.774647e+04
# 2     BEEF      BRA  2.717693e+05
# 3     BEEF    BRICS  6.869837e+05
# 4     BEEF      CAN  3.881240e+04
# 5     BEEF      CHE  6.995972e+03
# 6     BEEF      CHL  1.623483e+04
# 7     BEEF      CHN  2.263449e+05
# 8     BEEF      COL  3.021523e+04
# 9     BEEF      EGY  3.770019e+04
# 10    BEEF      ETH  1.386649e+04
# 11    BEEF     EU27  2.009691e+05
# 12    BEEF      GBR  3.065074e+04
# 13    BEEF      IDN  2.255251e+04
# 14    BEEF      IND  5.968945e+04
# 15    BEEF      IRN  1.978166e+04
# 16    BEEF      ISR  8.084814e+03
# 17    BEEF      JPN  5.106927e+04
# 18    BEEF      KAZ  1.987030e+04
# 19    BEEF      KOR  2.392809e+04
# 20    BEEF      MEX  6.072644e+04
# 21    BEEF      MYS  7.634604e+03
# 22    BEEF      NGA  1.332203e+04
# 23    BEEF      NOR  4.308281e+03
# 24    BEEF      NZL  4.779522e+03
# 25    BEEF     OECD  9.724720e+05
# ...

# %%
X = pd.merge(data1, data2, on='location', how='inner')
X
# Out:
#    subject_x location  Sum of value_x subject_y  Sum of value_y
# 0      SHEEP      ARG     2245.512499   POULTRY    5.393800e+04
# 1      SHEEP      AUS    10933.888020   POULTRY    3.726184e+04
# 2      SHEEP      BRA     4752.071549   POULTRY    2.752745e+05
# 3      SHEEP    BRICS   192789.180700   POULTRY    1.131228e+06
# 4      SHEEP      CAN     1367.495218   POULTRY    4.788905e+04
# 5      SHEEP      CHE      532.502647   POULTRY    5.006929e+03
# 6      SHEEP      CHL      431.226326   POULTRY    2.277114e+04
# 7      SHEEP      CHN   145444.401300   POULTRY    5.717047e+05
# 8      SHEEP      COL      414.180367   POULTRY    4.581553e+04
# 9      SHEEP      EGY     4847.806018   POULTRY    3.794192e+04
# 10     SHEEP      ETH     3061.113745   POULTRY    1.329717e+03
# 11     SHEEP     EU27    24445.099790   POULTRY    3.073802e+05
# 12     SHEEP      GBR     9818.353170   POULTRY    5.712313e+04
# 13     SHEEP      IDN     4596.794790   POULTRY    6.317912e+04
# ...

# %%
Y= pd.merge(data3,data4, on='location',how='inner')
Y
# Out:
#    subject_x location  Sum of value_x subject_y  Sum of value_y
# 0        PIG      ARG    1.623060e+04      BEEF    9.811123e+04
# 1        PIG      AUS    2.183077e+04      BEEF    2.774647e+04
# 2        PIG      BRA    1.010892e+05      BEEF    2.717693e+05
# 3        PIG    BRICS    2.049493e+06      BEEF    6.869837e+05
# 4        PIG      CAN    3.164899e+04      BEEF    3.881240e+04
# 5        PIG      CHE    1.082451e+04      BEEF    6.995972e+03
# 6        PIG      CHL    1.418065e+04      BEEF    1.623483e+04
# 7        PIG      CHN    1.814999e+06      BEEF    2.263449e+05
# 8        PIG      COL    1.191381e+04      BEEF    3.021523e+04
# 9        PIG      EGY    7.808260e+01      BEEF    3.770019e+04
# 10       PIG      ETH    7.036734e+01      BEEF    1.386649e+04
# 11       PIG     EU27    5.712216e+05      BEEF    2.009691e+05
# 12       PIG      GBR    4.141691e+04      BEEF    3.065074e+04
# 13       PIG      IDN    1.535225e+04      BEEF    2.255251e+04
# ...

# %%
Z=pd.merge(X,Y, on='location',how='inner')
Z.sample(5)
# Out:
#    subject_x_x location  Sum of value_x_x subject_y_x  Sum of value_y_x
# 7        SHEEP      CHN     145444.401300     POULTRY      571704.74290  \
# 6        SHEEP      CHL        431.226326     POULTRY       22771.13938
# 1        SHEEP      AUS      10933.888020     POULTRY       37261.83593
# 9        SHEEP      EGY       4847.806018     POULTRY       37941.91615
# 11       SHEEP     EU27      24445.099790     POULTRY      307380.21360
#
#    subject_x_y  Sum of value_x_y subject_y_y  Sum of value_y_y
# 7          PIG      1.814999e+06        BEEF      226344.93950
# 6          PIG      1.418065e+04        BEEF       16234.82638
# 1          PIG      2.183077e+04        BEEF       27746.47275
# 9          PIG      7.808260e+01        BEEF       37700.19122
# 11         PIG      5.712216e+05        BEEF      200969.10470

# %%
new_order=['location','subject_x_x','Sum of value_x_x','subject_y_x','Sum of value_y_x','subject_x_y','Sum of value_x_y','subject_y_y','Sum of value_y_y']

# %%
K = Z.reindex(columns=new_order)
K
# Out:
#    location subject_x_x  Sum of value_x_x subject_y_x  Sum of value_y_x
# 0       ARG       SHEEP       2245.512499     POULTRY      5.393800e+04  \
# 1       AUS       SHEEP      10933.888020     POULTRY      3.726184e+04
# 2       BRA       SHEEP       4752.071549     POULTRY      2.752745e+05
# 3     BRICS       SHEEP     192789.180700     POULTRY      1.131228e+06
# 4       CAN       SHEEP       1367.495218     POULTRY      4.788905e+04
# 5       CHE       SHEEP        532.502647     POULTRY      5.006929e+03
# 6       CHL       SHEEP        431.226326     POULTRY      2.277114e+04
# 7       CHN       SHEEP     145444.401300     POULTRY      5.717047e+05
# 8       COL       SHEEP        414.180367     POULTRY      4.581553e+04
# 9       EGY       SHEEP       4847.806018     POULTRY      3.794192e+04
# 10      ETH       SHEEP       3061.113745     POULTRY      1.329717e+03
# 11     EU27       SHEEP      24445.099790     POULTRY      3.073802e+05
# ...

# %%
K.to_csv('Newdataset', index=False) # set index=False to exclude row numbers
